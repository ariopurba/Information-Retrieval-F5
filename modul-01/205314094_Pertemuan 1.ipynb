# %% [markdown]
# # MODUL 1
# ### PENGENALAN PYTHON
# A. Tujuan
# <br><br>
#     1. Mahasiswa diharapkan mengenal bahasa pemrograman python.<br>
#     2. Mahasiswa diharapkan menggunakan bahasa pemrograman python.
# <br>
#     3. Mahasiswa diharapkan mengetahui perbedaan bahasa pemrograman python dengan bahasa lain.
# <br><br>
# B. Teori
# <br><br>
#     Python merupakan bahasa tingkat tinggi, yang diciptakan oleh Guido van Rossum dan
# diliris pertama kali pada tahun 1991, bersifat case sensitive bahasa ini dibuat seringkas mungkin
# dari bahasa – bahasa lainnya sehingga beberapa bagian dihilangkan seperti tidak perlunya
# deklarasi jenis atau type variable (walaupun sebenarnya tipe data dideklarasikan otomatis),
# hilangnya tanda kurung kurawal {} dan titik koma ; pada akhir perintah. Untuk membedakan
# susunan perintah, digunakan delimit block code atau indent atau fungsi tab.
#
#   <br><br>

# %% [markdown]
# ### Latihan Dasar

# %% [markdown]
# #### Latihan 1

# %%
xa = "Pemerolehan Informasi"
xa = 3
print(xa) #Akan menampilkan angka 3
# Out:
# 3

# %%
xa = "Pemerolehan Informasi"
xa = 3
xa = 3.1
print(xa) #akan menampilkan angka 3
# Out:
# 3.1

# %%
xa = "Pemerolehan Informasi"
xa = 3
print(xa) #akan menampilkan angka 3

# %% [markdown]
# #### Latihan 2

# %%
x = 3 #int
print(x) #Akan menampilkan angka 3 bertipe integer

# %%
x = 3 #int
print(x) #Akan menampilkan angka 3 bertipe integer
x = float(x) #int
# functions float() akan mengubah angka yang awalnya bertipe integer --> tipe float
print(x) #Akan menampilkan angka 3.0 bertipe data float

# %% [markdown]
# #### Latihan 3

# %%
if 5 > 2:
  print("five greater than two")
# Out:
# five greater than two

# %%
if 5 > 2:
print("five greater than two") #Akan menampilkan pesan error dikarenakan indentasi pada python salah

# %% [markdown]
# #### Latihan 4

# %%
thn_masuk = 2020
x = 2022
if x == thn_masuk:
  print("Selamat Datang Mahasiswa Baru")
else:
  y = x - thn_masuk
  print("Selamat Datang Anda Telah Melewati tahun ke-{}".format(y))
  if y == 1:
    print("Anda telah mengambil matkul Algoritma dan Pemrograman")
  elif y==2:
    print("Anda telah mengambil matkul Pemrograman")
  elif y == 3:
    print("Anda telah memilih 1 bidang minat dari 3 bidang minat")
  else:
    print("Anda sedang mengambil metopen atau skripsi")

# %% [markdown]
# #### Latihan 5

# %%
x = 0
while x < 10:
  x += 1
  if x == 10:
    break
  elif x%2 is not 0:
    print("{} merupakan bilangan ganjil".format(x))
  else:
    print("{} merupakan bilangan genap".format(x))

# %% [markdown]
# #### Latihan 6

# %%
nama = ["Alice", "Bob", "Charlie", "Donny" ]
x = 0
while x < len(nama):
  print(nama[x])
  x += 1
  #Menggunakan perulangan while untuk menampilkan isi dari array nama

# %%
nama = ["Alice","Bob", "Charlie", "Donny"]
for x in nama:
  print(x) #Menggunakan perluangan for untuk menampilkan isi dari array nama

# %% [markdown]
# #### Latihan 7

# %%
def fibonnaci(x):
    if x <= 1:
     return 0
    elif x == 2:
     return 1
    else:
      x1 = fibonnaci(x-1)
      x2 = fibonnaci(x-2)
      return x1+x2
x = int(input("Masukkan angka:"))
print(fibonnaci(x))

# %% [markdown]
# #### Latihan 8

# %%
def fibonnaci(x):
  if x < 0:
    return 0
  elif x == 2 or x == 1:
    return 1
  elif x>2:
    x1 = fibonnaci(x-1)
    x2 = fibonnaci(x-2)
    x1+x2
    return x1+x2
x = int(input("Masukkan Angka: "))
i = 0
while i<x-1:
    i+=1
    j = 0
    txt=""
    while j<i:
      j+=1
      txt+= str(fibonnaci(j))
    print(txt)

# %% [markdown]
# ### Latihan String

# %% [markdown]
# #### Latihan 1

# %%
x = "Hello World!"
print(x[6]) #Akan menampilkan huruf W karena karena huruf W berada pada index ke 6
# Out:
# W

# %% [markdown]
# #### Latihan 2

# %%
x = "Hello World!"
print(x[1:5]) #Akan menampilkan/mengambil String pada index 1-5
# Out:
# ello

# %%
x = "Hello World"
print(x[-5:-2]) #akan menampilkan/mengambil String pada dimulai dari index belakang

# %% [markdown]
# #### Latihan 3

# %%
x = "Hello World!"
print(len(x))

# %% [markdown]
# #### Latihan 4

# %%
x = "     Hello World!"
print(x.strip()) #Akan menghapus ruang di awal string

# %% [markdown]
# #### Latihan 5

# %%
x = "Hello World!"
print(x.upper()) #Untuk mengembalikan string dimana semua karakter dalam huruf besar
# Out:
# HELLO WORLD!

# %%
x = "Hello World!"
print(x.lower())#Untuk mengembalikan string dimana semua karakter dalam huruf kecil

# %% [markdown]
# #### Latihan 6

# %%
x = "Hello World!"
print(x.replace("H", "G") # akan error karena kurang tutup kurung

# %%
#Perbaikan error
x = "Hello World!"
print(x.replace("H", "G"))

# %% [markdown]
# #### Latihan 7

# %%
x = "Hello World!"
print(x.split(" ")) #Fungsi Split() untuk mengubah string menjadi sebuah list pada python
# Out:
# ['Hello', 'World!']

# %% [markdown]
# #### Latihan 8

# %%
x = "One of only four orangutan sanctuaries in the world, Sepilok is about 25 km north of Sandakan. The center was established in 1964; it now covers 40 sq km and has become one of Sabah's top tourist attractions."
f = "top" in x #
print(f)
f = "top" not in x
print(f)

# %% [markdown]
# #### Latihan 9

# %%
x = "Saya mahasiswa"
y = "angkatan {}"
t = 2020
a = x+y
print(a.format(t))

# %% [markdown]
# #### Latihan 10

# %%
x = "Saya {} lahir {}"
y = "angkatan {}"
z = "sekarang kuliah di tahun {}"
n ="Ario Tua Purba"
l ="03-08-2002"
t ="2020"
y = 2019
a = x+y+z #Akan menampilkan pesan error dimana pada python untuk menggabungkan hanya dapat dilakukan pada tipe data string bukan int (y)
print(a.format(n, l, t, y))

#Perbaikan error
x = "Saya {} lahir {}"
y = "angkatan {}"
z = "sekarang kuliah di tahun {}"
n ="Ario Tua Purba"
l ="03-08-2002"
t ="2020"
y = "2019"
a = x+y+z 
print(a.format(n, l, t, y))

# %%
x = "Saya {0}, angkatan {2} dan lulus tahun {1}"
n ="Ario Tua Purba"
l = "2024"
t = "2020"
print(x.format(n, t, l)) #akan menampilkan nama kemudian angkatan lalu lulus tahun
